# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3 as sql

# %%
df = pd.read_csv('../gronagarden_data.csv')

# %% [markdown]
# # 1. EDA
# I denna notebook läser vi in rådata och kollar på vad som ska städas, som jag vidare kan skapa att göra lista

# %%
df.head()
# Out:
#         order_id      orderrad_id      orderdatum önskat_leveransdatum  \
# 0  GG-2024-00001  GG-2024-00001-1      2024-01-01           2024-01-05
# 1  GG-2024-00002  GG-2024-00002-1      2024-01-07           2024-01-12
# 2  GG-2024-00002  GG-2024-00002-2      2024-01-07           2024-01-12
# 3  GG-2024-00002  GG-2024-00002-3  7 januari 2024           2024-01-12
# 4  GG-2024-00003  GG-2024-00003-1      2024-01-04           2024-01-13
#
#   faktiskt_leveransdatum   produkt_id           produktnamn       kategori  \
# 0             2024-01-05  PLT-INO-003       Gullranka ampel  Inomhusväxter
# 1             2024-01-12  FRO-TOM-001  Tomatfrön 'Tiny Tim'           Frön
# 2             2024-01-12  PLT-INO-001    Monstera deliciosa  Inomhusväxter
# 3             2024-01-12  JOR-NAR-001             Näring 1L  Jord & näring
# 4             2024-01-03  FRO-ORT-001             Örter mix           Frön
#
#       säsong antal   pris  vikt_gram leveranszon     kund_id  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2399 entries, 0 to 2398
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   order_id                2399 non-null   str
#  1   orderrad_id             2399 non-null   str
#  2   orderdatum              2399 non-null   str
#  3   önskat_leveransdatum    2223 non-null   str
#  4   faktiskt_leveransdatum  2399 non-null   str
#  5   produkt_id              2399 non-null   str
#  6   produktnamn             2399 non-null   str
#  7   kategori                2399 non-null   str
#  8   säsong                  2308 non-null   str
#  9   antal                   2399 non-null   str
#  10  pris                    2399 non-null   str
#  11  vikt_gram               2399 non-null   str
#  12  leveranszon             2243 non-null   str
#  13  kund_id                 2399 non-null   str
#  14  recension_text          1038 non-null   str
# ...

# %%
df.isna().sum()
# Out:
# order_id                     0
# orderrad_id                  0
# orderdatum                   0
# önskat_leveransdatum       176
# faktiskt_leveransdatum       0
# produkt_id                   0
# produktnamn                  0
# kategori                     0
# säsong                      91
# antal                        0
# pris                         0
# vikt_gram                    0
# leveranszon                156
# kund_id                      0
# recension_text            1361
# recensionsdatum           1361
# betyg                     1361
# dtype: int64

# %%
unika_namn = sorted(df['produktnamn'].dropna().unique())

for namn in unika_namn:
    print(namn)
# Out:
# BASILIKAPLANTA
# Balkong låda 60
# Balkonglåda plast
# Basilika
# Basilika persilja dill
# Basilika planta
# Basilikaplanta
# Bassilika
# Bifftomat frön
# Bifftomat planta
# Bifftommat
# Blomfrön sommar
# Blomjord 25L
# Blomjord 50L
# FLYTANDE NÄRING
# FREDSKALLA
# Flytande näring 1L
# Freds kalla
# Fredskalla
# Fredslilja
# GULLRANKA AMPEL
# GURKFRÖN
# Gullranka
# Gullranka ampel
# Gullranka hängande
# Gurk frön Marketmore
# Gurka Marketmore
# Gurkfrö
# Gurkfrön 'Marketmore'
# Gödsel flytande
# Jord 25L
# Jord 50L
# Körsbärstomat Tiny Tim
# Lerkruka 15cm
# Lerkruka 25cm
# Monstera
# Monstera Deliciosa
# Monstera deliciosa
# NARCISSLÖKAR
# Narciss lökar
# Narcisser 15st
# Narcisslökar 15-pack
# Näring 1L
# PELARGON RÖD
# PERSILJA I KRUKA
# PETUNIA MIX
# PLANTERINGSJORD 25L
# PLANTERINGSJORD 50L
# PLASTLÅDA BALKONG
# Pelargon Röd
# Pelargon röd
# Pelargoner röd
# Persilja i kruka
# Persilja i kruuka
# Perssilja
# Petunia blandning
# Petunia mix
# Petunior mix
# ...

# %% [markdown]
# Här ser vi hur rådatan ser ut, väldigt stökig, datum tolkas som text, null värde, dubbletter

# %% [markdown]
# # To do list:
# * Ändra till rätt typer
# * Städa kolumner/rader (format, text, siffror, dubeltter)
# * Hantera null värde
